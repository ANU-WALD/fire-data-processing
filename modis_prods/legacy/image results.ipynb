# %% [markdown]
# # This is the output of the algorithm with SA formula

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

a = np.load("/Users/pablo/Desktop/marta/MCD43A4.A2002249.h30v12.005.2007201174136_NDVI_SA.npy")
print(a.shape)
print(a.dtype)
print(a[1100,500])
a[a==0.0] = np.nan
plt.imshow(a)
# Out:
# (2400, 2400)
# float32
# 270.59
# /Users/pablo/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

a = np.load("/Users/pablo/Desktop/marta/MCD43A4.A2002249.h30v12.005.2007201174136_SA5.npy")
print(a.shape)
print(a.dtype)
print(a[1100,500])
a[a==0.0] = np.nan
plt.imshow(a)
# Out:
# (2400, 2400)
# float32
# 270.59

# %% [markdown]
# # This is the output of your algorithm

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from osgeo import gdal
import numpy as np

ds = gdal.Open("/Users/pablo/Desktop/FMC_ACT_h30v122002.09.06.tif")
b = ds.GetRasterBand(1).ReadAsArray()

print(b.shape)
print(b.dtype)
print(b[1100,500])
plt.imshow(b)
# Out:
# (2400, 2400)
# float32
# 270.59

# %% [markdown]
# # As you can see we now get the exact same results. Yeiii!!!

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.load("/Users/pablo/Desktop/MCD43A4.A2002249.h30v12.005.2007201174136.npy")
print(a.shape)
print(a.dtype)
print(a[1100,500])
a[a==0.0] = np.nan
plt.imshow(a)
# Out:
# (2400, 2400)
# float32
# 0.0
